# %%
import pandas as pd
import os

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('train.csv')
#
# File c:\Users\ANKIT SHARMA\miniconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ANKIT SHARMA\miniconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df.columns
# Out:
# Index(['2', 'Stuning even for the non-gamer',
#        'This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^'],
#       dtype='object')

# %%
df = df.rename(columns={'2' : 'Boolean', 'Stuning even for the non-gamer':'Subject',
       'This sound track was beautiful! It paints the senery in your mind so well I would recomend it even to people who hate vid. game music! I have played the game Chrono Cross but out of all of the games I have ever played it has the best music! It backs away from crude keyboarding and takes a fresher step with grate guitars and soulful orchestras. It would impress anyone who cares to listen! ^_^':'Review',
     } )
df.tail()
# Out:
#          Boolean                                Subject  \
# 3599994        1                          Don't do it!!
# 3599995        1          Looks nice, low functionality
# 3599996        1             compact, but hard to clean
# 3599997        1                     what is it saying?
# 3599998        2  Makes My Blood Run Red-White-And-Blue
#
#                                                     Review
# 3599994  The high chair looks great when it first comes...
# 3599995  I have used this highchair for 2 kids now and ...
# 3599996  We have a small house, and really wanted two o...
# 3599997  not sure what this book is supposed to be. It ...
# 3599998  I agree that every American should read this b...

# %%
df.shape
# Out:
# (3599999, 3)

# %%
ndf = df.copy()

# %%
#pd.set_option('display.max_colwidth', None) # To display the whole text of the given cell
#pd.reset_option('display.max_colwidth') # To Reverse above option
ndf.loc[3555555]
# Out:
# Boolean                                                                                                                                                                                                                                                                                                                      2
# Subject                                                                                                                                                                                                                                                                                              Drunken philosophy kungfu
# Review     Philosophical martial arts film, with some creative fight choreography for its time. The Red Clay Village scenery was beautiful (most likely even more spectacular back when the film was originally released). This film reminds of a mix between "Dangerous Minds" and "Drunken Master"!!! Nice film for its era.
# Name: 3555555, dtype: object

# %%
ndf['Boolean'].value_counts()
# Out:
# 1    1800000
# 2    1799999
# Name: Boolean, dtype: int64

# %%
ax = ndf['Boolean'].value_counts().sort_index().plot(kind='bar',
          title='Negative Vs Positive',
          figsize=(5, 3))
ax.set_xlabel('Reviews')
# Out:
# Text(0.5, 0, 'Reviews')

# %%
example  = ndf['Review'][50]
print(example)
# Out:
# The first one I bought was defective. The DVD didn't work at all. I purchased it from Electronics Express and when I contacted them they were wonderful. They gave me an RMA number right away, Fedex picked it up the next day and a new one arrived 1 week later. This one is just fine. I really love the clarity of the picture. My only complaint is that in DVD mode, the sound isn't loud enough. I have it in my RV and with the A/C running, I can barely hear it. I solved the problem by running an audio out jack from the TV to the input on the RV stereo speaker system. It's very lightweight and easy to move around and store. A bonus for the RV. The remote isn't great, but it works just fine and the video/audio jacks and antenna input are easy to get to as is the DVD player. All in all, it's a great deal for the price.

# %% [markdown]
# ## DataStructures
# ### Series
# ### Dataframe

# %%
mydata = ['Boat' , 'Car' , 'Bike' , 'Truck']
myseries1  = pd.Series(mydata)

# %%
print(myseries1)
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# dtype: object

# %%
mydata = [1,55,49,43]
myseries2 = pd.Series(mydata)
print(myseries2)
# Out:
# 0     1
# 1    55
# 2    49
# 3    43
# dtype: int64

# %%
mydfdata = [('Boat' , 1) , ('Car' , 55) , ('Bike',49) , ('Truck',43)]
mydf = pd.DataFrame(mydfdata) # Think of dataframe as a spredsheet
mydf
# Out:
#        0   1
# 0   Boat   1
# 1    Car  55
# 2   Bike  49
# 3  Truck  43

# %%
df = [('ankit' , 25 , 95 , 86) , ('ankit' , 25 , 55 , 87) , ('ankit' , 25 , 65 , 84) , ('ankit' , 25 , 75 , 42) 
      ,('ankit' , 25 , 35 , 99) , ('anurag' , 27 , 83 , 77) , ('anurag' , 27 , 85 , 73) , ('anurag' , 27 , 91 , 55)]
mydf = pd.DataFrame(df , columns = ['Name' , 'Age' , 'Marks' , 'Weight'])
mydf
# Out:
#      Name  Age  Marks  Weight
# 0   ankit   25     95      86
# 1   ankit   25     55      87
# 2   ankit   25     65      84
# 3   ankit   25     75      42
# 4   ankit   25     35      99
# 5  anurag   27     83      77
# 6  anurag   27     85      73
# 7  anurag   27     91      55

# %%
mydf.groupby(['Name' , 'Age'] , as_index = False).max() # picks the max of EVERY column in the group
mydf.groupby(['Name' , 'Age'] , as_index = False).min() # picks the min of every column in the group
# Out:
#      Name  Age  Marks  Weight
# 0   ankit   25     35      42
# 1  anurag   27     83      55

# %%
#Adding names to the column
mydfdata = [('Boat' , 1) , ('Car' , 55) , ('Bike',49) , ('Truck',43)]
mydf = pd.DataFrame(mydfdata , columns = ['thing' , 'count']) # Think of dataframe as a spredsheet
mydf
# Out:
#    thing  count
# 0   Boat      1
# 1    Car     55
# 2   Bike     49
# 3  Truck     43

# %%
# calling the specific column
mydf['thing']
# Out:
# 0     Boat
# 1      Car
# 2     Bike
# 3    Truck
# Name: thing, dtype: object

# %%
# to see datatypes of all differet columns
mydf.dtypes
# Out:
# thing    object
# count     int64
# dtype: object

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# ## Reading different data

# %%
df = pd.read_csv('nba.csv')

# %% [markdown]
# ### Inspecting the data

# %%
df.head()# to see first 5 columns by default(can type custom value in the bracket) and get an overview
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
df.tail() # to see bottom 5
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df.describe()#works only for the numeric columns
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# ## Columns and rows

# %%
df['Age'] # Enter the name of the column to output it
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
#        ...
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %%
df.loc[4] # outputs all the columns for this index of the row
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.set_index('Name' , inplace = True) # you can set index to any column

# %%
df.loc['Jonas Jerebko'] # Once index is set to a given column , its value can be used to call the row
# Out:
# Team        Boston Celtics
# Number                 8.0
# Position                PF
# Age                   29.0
# Height                6-10
# Weight               231.0
# College                NaN
# Salary           5000000.0
# Name: Jonas Jerebko, dtype: object

# %% [markdown]
# ## Subsetting the data

# %%
df.columns
# Out:
# Index(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#        'Salary'],
#       dtype='object')

# %%
# Subsetting columns
# Keeping only the columns that you want to keep

df = df[['Team', 'Number', 'Position', 'College',
       'Salary']] # By doing this you can keep only the columns that you want to keep

# %%
df.head()
# Out:
#                          Team  Number Position            College     Salary
# Name
# Avery Bradley  Boston Celtics     0.0       PG              Texas  7730337.0
# Jae Crowder    Boston Celtics    99.0       SF          Marquette  6796117.0
# John Holland   Boston Celtics    30.0       SG  Boston University        NaN
# R.J. Hunter    Boston Celtics    28.0       SG      Georgia State  1148640.0
# Jonas Jerebko  Boston Celtics     8.0       PF                NaN  5000000.0

# %%
df.shape
# Out:
# (458, 5)

# %%
#Subsetting rows

df['Salary'] > 5_00_000 # Shows if the row satisfy the condition next to the index of the row
# Out:
# Name
# Avery Bradley     True
# Jae Crowder       True
# John Holland     False
# R.J. Hunter       True
# Jonas Jerebko     True
#                  ...
# Shelvin Mack      True
# Raul Neto         True
# Tibor Pleiss      True
# Jeff Withey       True
# NaN              False
# Name: Salary, Length: 458, dtype: bool

# %%
#Subsetting using loc
df_subset1 = df.loc[df['Salary'] > 5_00_000] # Using the combination of loc with it . would output only the ones who satisfy this condition

# %%
df_subset2 = df.query('Salary > 5_00_000') # a little cleaner way of achieveing the same aim

# %%
df.loc[df['Age'].isna()] # to look for the null values
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN

# %%
df.loc[~df['Age'].isna()] # Opposite of above

# %% [markdown]
# ## Casting dtypes
# i.e to change the data type of a given column

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age           int32
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df['Age'] = df['Age'].astype('int') # if a column has null value than it is of float types . Otherwise it can be changed to int type.

# %% [markdown]
# # Creating new column

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df['BMI'] = df['Weight'] / df['Age']

# %% [markdown]
# ## Adding new row

# %%
df_to_append = df.tail(1)

# %%
df_concat = pd.concat([df , df_to_append]) # Adds the same row

# %% [markdown]
# ## Plot Example

# %%
df['Age'].plot(kind = 'hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['Age'].plot(kind = 'hist' , bins = 50  ,title = 'Distribution of Age' , figsize = (15,5))
# Out:
# <AxesSubplot: title={'center': 'Distribution of Age'}, ylabel='Frequency'>

# %%
df.plot(kind = 'scatter' , x = 'Height', y = 'Weight' , title = 'Height Vs Weight')
# Out:
# <AxesSubplot: title={'center': 'Height Vs Weight'}, xlabel='Height', ylabel='Weight'>

# %%
bk = df.query('Weight > 260')

# %%
bk
df # only the last dataframe is shown
# By default, when you execute a code cell containing a DataFrame in a Jupyter notebook or a Python script,
#  only the last DataFrame in that code cell will be displayed in the output. However, you can display multiple DataFrames by 
# calling their respective variables or by using the print() function to explicitly display them.
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF   25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG   27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG   22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF   29   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG   26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG   24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C   26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C   26    7-0   231.0
#
#                College     Salary        BMI
# 0                Texas  7730337.0   7.200000
# ...

# %%
bk.shape
# Out:
# (26, 10)

# %% [markdown]
# ## Save our output

# %%
df.to_csv('Processed_data.csv' , index = False)

# %%
series_test = list(range(1,100))
pd.Series(series_test)
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 94    95
# 95    96
# 96    97
# 97    98
# 98    99
# Length: 99, dtype: int64

# %%
pwd = os.getcwd()

# %%
os.getcwd()
# Out:
# 'c:\\Users\\ANKIT SHARMA\\AppData\\Local\\Programs\\Microsoft VS Code'

# %%
pwd
# Out:
# 'c:\\Users\\ANKIT SHARMA\\Desktop\\Shashank kalanithi\\Python tutorial'

# %%
import sys

print(sys.path[0])
# Out:
# c:\Users\ANKIT SHARMA\Desktop\Shashank kalanithi\Python tutorial

# %%
filepath = pwd + "\\simple_csv.csv" # never forget to put the backslash or two forward slash (\\) , otherwise ERROR 2 : file not found error will be there
#filepath

# %%
os.path.exists(filepath)
# Out:
# True

# %%
first_import = pd.read_csv(filepath, nrows=10)
first_import
# Out:
#     Column1   Column2   Column3
# 0  0.280925  0.910368  0.692982
# 1  0.719882  0.210024  0.761276
# 2  0.235752  0.059796  0.154667
# 3  0.603366  0.485614  0.013345
# 4  0.039985  0.236359  0.811832
# 5  0.015478  0.543641  0.112719
# 6  0.192540  0.409874  0.875082
# 7  0.380921  0.045468  0.515859
# 8  0.592471  0.786421  0.047249
# 9  0.072112  0.695694  0.409573

# %%
first_import["Column3"]
# Out:
# 0    0.692982
# 1    0.761276
# 2    0.154667
# 3    0.013345
# 4    0.811832
# 5    0.112719
# 6    0.875082
# 7    0.515859
# 8    0.047249
# 9    0.409573
# Name: Column3, dtype: float64

# %%
first_import["new _column"] = 1
first_import["newcolumn 2"] = list(range(10))
first_import["added output"] = first_import["new _column"] + first_import["newcolumn 2"]
first_import
# Out:
#     Column1   Column2   Column3  new _column  newcolumn 2  added output
# 0  0.280925  0.910368  0.692982            1            0             1
# 1  0.719882  0.210024  0.761276            1            1             2
# 2  0.235752  0.059796  0.154667            1            2             3
# 3  0.603366  0.485614  0.013345            1            3             4
# 4  0.039985  0.236359  0.811832            1            4             5
# 5  0.015478  0.543641  0.112719            1            5             6
# 6  0.192540  0.409874  0.875082            1            6             7
# 7  0.380921  0.045468  0.515859            1            7             8
# 8  0.592471  0.786421  0.047249            1            8             9
# 9  0.072112  0.695694  0.409573            1            9            10

# %%
first_import = first_import.drop(columns = "new _column")
first_import
# Out:
#     Column1   Column2   Column3  newcolumn 2  added output
# 0  0.280925  0.910368  0.692982            0             1
# 1  0.719882  0.210024  0.761276            1             2
# 2  0.235752  0.059796  0.154667            2             3
# 3  0.603366  0.485614  0.013345            3             4
# 4  0.039985  0.236359  0.811832            4             5
# 5  0.015478  0.543641  0.112719            5             6
# 6  0.192540  0.409874  0.875082            6             7
# 7  0.380921  0.045468  0.515859            7             8
# 8  0.592471  0.786421  0.047249            8             9
# 9  0.072112  0.695694  0.409573            9            10

# %%
first_import.loc[:5 , ["Column1","Column2","Column3","newcolumn 2","added output"] ] # loc will include the last instance you specify
# This is like a vertical list
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.10.8)' due to connection timeout.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
first_import.iloc[:6,[0,2]] # first argument specify columns and 2nd = rows
# iloc selects data based on integer locatio
# loc selects data based on the label of the rows and columns.
# Out:
#     Column1   Column3
# 0  0.280925  0.692982
# 1  0.719882  0.761276
# 2  0.235752  0.154667
# 3  0.603366  0.013345
# 4  0.039985  0.811832
# 5  0.015478  0.112719

# %%
netflix = pd.read_csv( pwd + "/netflix_titles.csv")
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
list(netflix.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
netflix.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
netflix.corr()
# Out:
# C:\Users\ANKIT SHARMA\AppData\Local\Temp\ipykernel_6020\2461069083.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   netflix.corr()
#               release_year
# release_year           1.0

# %%
netflix["type"].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
netflix[netflix["country"]=="West Germany"]
# Out:
#      show_id   type              title                               director  \
# 2757   s2758  Movie  Hitler - A Career  Joachim Fest, Christian Herrendoerfer
#
#          cast       country         date_added  release_year rating duration  \
# 2757  no cast  West Germany  February 10, 2017          1977  TV-MA  150 min
#
#                                 listed_in  \
# 2757  Documentaries, International Movies
#
#                                             description computer_date  \
# 2757  This documentary examines how Adolf Hitler's t...    2017-02-10
#
#          unix_time  Date Part 1   Year  general_count  nonsensical_columns
# 2757  1.486685e+18  February 10   2017              2                    3

# %%
netflix[(netflix["country"] == "Singapore") & (netflix["rating"] == "TV-MA")]
# Out:
#      show_id     type                           title       director  \
# 2093   s2094    Movie      Fakkah Fuzz: Almost Banned  Michael McKay
# 2956   s2957    Movie                       Imperfect    Steve Cheng
# 3528   s3529    Movie                       Lang Tong        Sam Loh
# 4138   s4139    Movie  Miss J Contemplates Her Choice      Jason Lai
# 6949   s6950  TV Show               The Truth Seekers            NaN
#
#                                                    cast    country  \
# 2093                                        Fakkah Fuzz  Singapore
# 2956  Edwin Goh, Ian Fang Weijie, Phua Yida, Kimberl...  Singapore
# 3528  William Lawandi, Angeline Yap, Vivienne Tseng,...  Singapore
# 4138  Kit Chan, Xiang Yun, Bobby Tonelli, Shane Pow,...  Singapore
# 6949  Chen Hanwei, Rebecca Lim, Desmond Tan, Yusuke ...  Singapore
#
#              date_added  release_year rating  duration  \
# 2093   January 26, 2018          2018  TV-MA    61 min
# ...

# %%
netflix[(netflix["country"] == "Singapore") | (netflix["rating"] == "TV-MA")]  # pipe means or
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 5         s6  TV Show                                       46
# 6         s7    Movie                                      122
# ...      ...      ...                                      ...
# 7779   s7780  TV Show                                Zona Rosa
# 7780   s7781    Movie                                      Zoo
# 7782   s7783    Movie                                     Zozo
# 7784   s7785    Movie                        Zulu Man in Japan
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
2021-01-12   # always write like this
# Out:
#   Cell In[156], line 1
#     2021-01-12   # always write like this
#          ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
computer_date = pd.to_datetime(netflix["date_added"]) #NaN is same as null
computer_date
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7782   2020-10-19
# 7783   2019-03-02
# 7784   2020-09-25
# 7785   2020-10-31
# 7786   2020-03-01
# Name: date_added, Length: 7787, dtype: datetime64[ns]

# %%
netflix["computer_date"] = pd.to_datetime(netflix["date_added"]) #NaN is same as null
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix["computer_date"]
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7782   2020-10-19
# 7783   2019-03-02
# 7784   2020-09-25
# 7785   2020-10-31
# 7786   2020-03-01
# Name: computer_date, Length: 7787, dtype: datetime64[ns]

# %%
netflix["computer_date"].fillna(datetime)
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7782   2020-10-19
# 7783   2019-03-02
# 7784   2020-09-25
# 7785   2020-10-31
# 7786   2020-03-01
# Name: computer_date, Length: 7787, dtype: datetime64[ns]

# %%
netflix["computer_date"].dropna() # it shold return 7777 length
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7782   2020-10-19
# 7783   2019-03-02
# 7784   2020-09-25
# 7785   2020-10-31
# 7786   2020-03-01
# Name: computer_date, Length: 7787, dtype: datetime64[ns]

# %%
from datetime import datetime as dt

# %%
netflix["computer_date"].fillna(dt(2020, 1, 1), inplace= True)

# %%
netflix["unix_time"] = netflix["computer_date"].values.astype(int)  # shashank's code----->  netflix["unix_time"] = netflix["computer_date"].values.astype(float)

# %%
netflix  # look at the unix_time column
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix["date_added"].str.split(",", expand=True)
# Out:
#                  0      1
# 0        August 14   2020
# 1      December 23   2016
# 2      December 20   2018
# 3      November 16   2017
# 4        January 1   2020
# ...            ...    ...
# 7782    October 19   2020
# 7783       March 2   2019
# 7784  September 25   2020
# 7785    October 31   2020
# 7786       March 1   2020
#
# [7787 rows x 2 columns]

# %%
netflix[[" Date Part 1" , "Date Part 2"]] = netflix["date_added"].str.split(",", expand=True)
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
print('ankit')
print('anurag')
# Out:
# ankit
# anurag

# %%
netflix.rename(columns={"Date Part 2":"Year"} , inplace = True) # to rename the column
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix["cast"].fillna(value="no cast" , inplace = True) # pay attention to last row , NaN = no cast
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix["general_count"] = netflix["listed_in"].map(lambda x: len(x.split(","))) # returns the number of elements ( or number of genre i.e int tv shows , dramas , scifi etc)
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix["nonsensical_columns"] = netflix.apply(lambda x: len(x["cast"].split(",")) + len(x["listed_in"].split(",")) , axis= 1)  # number of cast memebers and numbe of genre are being added here
netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix.groupby("country")["show_id"].count().reset_index() # try with and without .reset_index() , it changes from  some funky object format to dataframe format , groupby is similar to sql
# Out:
#                                                country  show_id
# 0                                            Argentina       50
# 1    Argentina, Brazil, France, Poland, Germany, De...        1
# 2                                     Argentina, Chile        1
# 3                               Argentina, Chile, Peru        1
# 4                                    Argentina, France        1
# ..                                                 ...      ...
# 676                                          Venezuela        1
# 677                                Venezuela, Colombia        1
# 678                                            Vietnam        5
# 679                                       West Germany        1
# 680                                           Zimbabwe        1
#
# [681 rows x 2 columns]

# %%
print('hello')
# Out:
# hello

# %%
netflix_movies_by_country = netflix.groupby("country")["show_id"].count().reset_index() # to know which country makes the most movies
netflix_movies_by_country.sort_values(by ="show_id",ascending = False) # by default it is ascending , so to get value in descending this method is used
# Out:
#                                country  show_id
# 549                      United States     2555
# 229                              India      923
# 462                     United Kingdom      397
# 291                              Japan      226
# 394                        South Korea      183
# ..                                 ...      ...
# 252  Indonesia, South Korea, Singapore        1
# 253          Indonesia, United Kingdom        1
# 254           Indonesia, United States        1
# 255                       Iran, France        1
# 680                           Zimbabwe        1
#
# [681 rows x 2 columns]

# %%
second_datasheet = pd.read_csv(pwd +"/netflix_titles_second.csv") # here we are importing the second dataset
second_datasheet
# Out:
#     show_id     type                             title           director  \
# 0        s1  TV Show                                3%                NaN
# 1        s2    Movie                              7:19  Jorge Michel Grau
# 2        s3    Movie                             23:59       Gilbert Chan
# 3        s4    Movie                                 9        Shane Acker
# 4        s5    Movie                                21     Robert Luketic
# ..      ...      ...                               ...                ...
# 349    s350  TV Show  Ainori Love Wagon: Asian Journey                NaN
# 350    s351  TV Show          Ainsley Eats the Streets                NaN
# 351    s352    Movie                        Ainu Mosir   Takeshi Fukunaga
# 352    s353    Movie                     Airplane Mode    César Rodrigues
# 353    s354    Movie                   Aisa Yeh Jahaan     Biswajeet Bora
#
#                                                   cast               country  \
# ...

# %% [markdown]
# **UNION**

# %%
new_dataset = pd.concat([netflix,second_datasheet]) # union first and second dataset ( i.e  sticking on top of one another)
new_dataset
# Out:
#     show_id     type                             title           director  \
# 0        s1  TV Show                                3%                NaN
# 1        s2    Movie                              7:19  Jorge Michel Grau
# 2        s3    Movie                             23:59       Gilbert Chan
# 3        s4    Movie                                 9        Shane Acker
# 4        s5    Movie                                21     Robert Luketic
# ..      ...      ...                               ...                ...
# 349    s350  TV Show  Ainori Love Wagon: Asian Journey                NaN
# 350    s351  TV Show          Ainsley Eats the Streets                NaN
# 351    s352    Movie                        Ainu Mosir   Takeshi Fukunaga
# 352    s353    Movie                     Airplane Mode    César Rodrigues
# 353    s354    Movie                   Aisa Yeh Jahaan     Biswajeet Bora
#
#                                                   cast               country  \
# ...

# %% [markdown]
# **Joins**  , innere join , left join , right join , full join

# %%
netflix_merged = pd.merge( left=new_dataset , right=netflix_movies_by_country , how="inner" , left_on=["country"] , right_on=["country"] ) #  left side = new dataset , an inner join , on country column
netflix_merged
# Out:
#      show_id_x     type                      title  \
# 0           s1  TV Show                         3%
# 1         s209    Movie           A new Capitalism
# 2         s219  TV Show            A Queen Is Born
# 3         s321    Movie  Afonso Padilha: Classless
# 4         s323  TV Show        Afronta! Facing It!
# ...        ...      ...                        ...
# 7618     s7727    Movie               You Carry Me
# 7619     s7751  TV Show            Yu-Gi-Oh! Arc-V
# 7620     s7760  TV Show                  Zak Storm
# 7621     s7771    Movie                    Zinzana
# 7622     s7783    Movie                       Zozo
#
#                           director  \
# 0                              NaN
# 1                              NaN
# 2                     Carla Barros
# 3     Junior Carelli, Rudge Campos
# 4                  Juliana Vicente
# ...                            ...
# 7618                    Ivona Juka
# 7619                           NaN
# ...

# %%
netflix_merged = pd.merge( left=new_dataset , right=netflix_movies_by_country , how="inner" , left_on=["country"] , right_on=["country"] ) #  left side = new dataset , an inner join , on country column
netflix_merged
# Out:
#      show_id_x     type                      title  \
# 0           s1  TV Show                         3%
# 1         s209    Movie           A new Capitalism
# 2         s219  TV Show            A Queen Is Born
# 3         s321    Movie  Afonso Padilha: Classless
# 4         s323  TV Show        Afronta! Facing It!
# ...        ...      ...                        ...
# 7618     s7727    Movie               You Carry Me
# 7619     s7751  TV Show            Yu-Gi-Oh! Arc-V
# 7620     s7760  TV Show                  Zak Storm
# 7621     s7771    Movie                    Zinzana
# 7622     s7783    Movie                       Zozo
#
#                           director  \
# 0                              NaN
# 1                              NaN
# 2                     Carla Barros
# 3     Junior Carelli, Rudge Campos
# 4                  Juliana Vicente
# ...                            ...
# 7618                    Ivona Juka
# 7619                           NaN
# ...

# %%
# To select multiple cells at once
# https://github.com/microsoft/vscode/issues/157712

# %%
pwd = os.getcwd()

# %%
pwd
# Out:
# 'c:\\Users\\ANKIT SHARMA\\Desktop\\Shashank kalanithi\\Python tutorial'

# %%
#first_import = first_import.drop(columns = "new _column")
#
#
#
#
#
#
#

# %%
import pandas as pd
import os
import numpy as np

# %%
pwd = os.getcwd()

# %%
pwd
# Out:
# 'c:\\Users\\ANKIT SHARMA\\Desktop\\Shashank kalanithi\\Python tutorial'

# %%
#first_import = first_import.drop(columns = "new _column")
#
#
#
#
#
#
#

# %%
first = pd.read_csv( pwd + "/AQI (2015-2020).csv")
first
# Out:
#      Year   O2  Xylene     CO      O3  Toluene   Benzene
# 0  2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 1  2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 2  2016.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 3  2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 4  2018.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 5  2019.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 6  2020.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 7     NaN  NaN     NaN    NaN     NaN      NaN       NaN

# %%
second = pd.read_csv( pwd + "/AQI (2017-2022).csv")
second
# Out:
#    Year  Date  Time     CO   Value   Year.1     Price
# 0  2017   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 1  2017   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 2  2018   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 3  2019   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 4  2020   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 5  2021   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 6  2022   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 7  2022   2.2  22.2  222.2  2222.2  22222.2  222222.2
# 8  2022   2.2  22.2  222.2  2222.2  22222.2  222222.2

# %%
#first.fillna('yes',inplace=True) # If inplace is not set to true than fillna DOES NOT change the original format
first.dropna(inplace = True) # It will not drop them until you add inplace = True
first
# Out:
#      Year   O2  Xylene     CO      O3  Toluene   Benzene
# 0  2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 1  2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 2  2016.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 3  2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 4  2018.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 5  2019.0  1.1    11.1  111.1  1111.1  11111.1  111111.1
# 6  2020.0  1.1    11.1  111.1  1111.1  11111.1  111111.1

# %%
list(first.columns)
# Out:
# ['Year', 'O2', 'Xylene', 'CO', 'O3', 'Toluene', 'Benzene']

# %%
first.describe()
# Out:
#               Year            O2        Xylene            CO            O3  \
# count     7.000000  7.000000e+00  7.000000e+00  7.000000e+00  7.000000e+00
# mean   2017.142857  1.100000e+00  1.110000e+01  1.111000e+02  1.111100e+03
# std       1.951800  2.398356e-16  1.918685e-15  1.534948e-14  2.455916e-13
# min    2015.000000  1.100000e+00  1.110000e+01  1.111000e+02  1.111100e+03
# 25%    2015.500000  1.100000e+00  1.110000e+01  1.111000e+02  1.111100e+03
# 50%    2017.000000  1.100000e+00  1.110000e+01  1.111000e+02  1.111100e+03
# 75%    2018.500000  1.100000e+00  1.110000e+01  1.111000e+02  1.111100e+03
# max    2020.000000  1.100000e+00  1.110000e+01  1.111000e+02  1.111100e+03
#
#             Toluene       Benzene
# count  7.000000e+00  7.000000e+00
# mean   1.111110e+04  1.111111e+05
# std    1.964733e-12  1.571786e-11
# min    1.111110e+04  1.111111e+05
# 25%    1.111110e+04  1.111111e+05
# 50%    1.111110e+04  1.111111e+05
# 75%    1.111110e+04  1.111111e+05
# ...

# %%
third = pd.concat([first,second]) # union first and second dataset ( i.e  sticking on top of one another)
third
# Out:
#      Year   O2  Xylene     CO      O3  Toluene   Benzene  Date  Time   Value  \
# 0  2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN     NaN
# 1  2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN     NaN
# 2  2016.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN     NaN
# 3  2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN     NaN
# 4  2018.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN     NaN
# 5  2019.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN     NaN
# 6  2020.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN     NaN
# 7     NaN  NaN     NaN    NaN     NaN      NaN       NaN   NaN   NaN     NaN
# 0  2017.0  NaN     NaN  222.2     NaN      NaN       NaN   2.2  22.2  2222.2
# 1  2017.0  NaN     NaN  222.2     NaN      NaN       NaN   2.2  22.2  2222.2
# 2  2018.0  NaN     NaN  222.2     NaN      NaN       NaN   2.2  22.2  2222.2
# ...

# %%
four = pd.merge( left=first , right=second , how="outer" , left_on=["Year"] , right_on=["Year"] , indicator=True ) #  left side = new dataset , an inner join , on country column
four
# Out:
#       Year   O2  Xylene   CO_x      O3  Toluene   Benzene  Date  Time   CO_y  \
# 0   2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 1   2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 2   2016.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 3   2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 4   2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 5   2018.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 6   2019.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 7   2020.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 8   2021.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# 9   2022.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# 10  2022.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# ...

# %%
four['O2'].dropna(inplace=True) # clean the data (i.e remove , replace 'na') beforehand . Otherwise it wont work after join
four
# Out:
#       Year   O2  Xylene   CO_x      O3  Toluene   Benzene  Date  Time   CO_y  \
# 0   2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 1   2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 2   2016.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 3   2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 4   2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 5   2018.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 6   2019.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 7   2020.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 8   2021.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# 9   2022.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# 10  2022.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# ...

# %%
four['CO'] = np.max(four[['CO_x', 'CO_y']], axis=1) # https://stackoverflow.com/questions/25762902/python-pandas-particular-merge-replacement
four # maximum() function is used to find the element-wise maximum of array elements. It compares two arrays and returns a new array containing 
# the element-wise maxima. If one of the elements being compared is a NaN, then that element is returned. If both elements are NaNs then the 
# first is returned.
# Out:
#       Year   O2  Xylene   CO_x      O3  Toluene   Benzene  Date  Time   CO_y  \
# 0   2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 1   2015.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 2   2016.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   NaN   NaN    NaN
# 3   2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 4   2017.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 5   2018.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 6   2019.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 7   2020.0  1.1    11.1  111.1  1111.1  11111.1  111111.1   2.2  22.2  222.2
# 8   2021.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# 9   2022.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# 10  2022.0  NaN     NaN    NaN     NaN      NaN       NaN   2.2  22.2  222.2
# ...

# %%
merged = four.drop(labels=['CO_x', 'CO_y','Date','Time','Year.1','Price','_merge','Value' ], axis=1)
merged
# Out:
#       Year   O2  Xylene      O3  Toluene   Benzene     CO
# 0   2015.0  1.1    11.1  1111.1  11111.1  111111.1  111.1
# 1   2015.0  1.1    11.1  1111.1  11111.1  111111.1  111.1
# 2   2016.0  1.1    11.1  1111.1  11111.1  111111.1  111.1
# 3   2017.0  1.1    11.1  1111.1  11111.1  111111.1  222.2
# 4   2017.0  1.1    11.1  1111.1  11111.1  111111.1  222.2
# 5   2018.0  1.1    11.1  1111.1  11111.1  111111.1  222.2
# 6   2019.0  1.1    11.1  1111.1  11111.1  111111.1  222.2
# 7   2020.0  1.1    11.1  1111.1  11111.1  111111.1  222.2
# 8   2021.0  NaN     NaN     NaN      NaN       NaN  222.2
# 9   2022.0  NaN     NaN     NaN      NaN       NaN  222.2
# 10  2022.0  NaN     NaN     NaN      NaN       NaN  222.2
# 11  2022.0  NaN     NaN     NaN      NaN       NaN  222.2

# %%
# https://www.kaggle.com/getting-started/40799

# %%
oki.loc[oki['City'].isin(['Ahmedabad','Delhi'])] # to select a specific row values based on a column
# loc is label-based, which means that we have to specify the name of the rows and columns that we need to filter out. 
# For example, let's say we search for the rows whose index is 1, 2 or 100.
# https://www.statology.org/pandas-select-rows-based-on-column-values/
# Out:
#             City       Date   PM2.5    PM10     NO    NO2    NOx    NH3    CO  \
# 741    Ahmedabad 2017-11-01     NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 742    Ahmedabad 2017-12-01     NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 772    Ahmedabad 2017-11-02     NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 773    Ahmedabad 2017-12-02     NaN     NaN    NaN    NaN    NaN    NaN   NaN
# 800    Ahmedabad 2017-11-03     NaN     NaN    NaN    NaN    NaN    NaN   NaN
# ...          ...        ...     ...     ...    ...    ...    ...    ...   ...
# 20673      Delhi 2023-01-28   60.34  151.22   1.91   5.82   7.72  43.49  0.68
# 20674      Delhi 2023-01-29   85.65  210.25   1.96   8.73  10.68  30.87  0.87
# 20675      Delhi 2023-01-30  108.72  275.49  40.46  19.01  54.72  83.19  1.83
# 20676      Delhi 2023-01-31   43.63  114.57   14.8   8.56  22.87   63.2  1.13
# 20677      Delhi 2023-01-02   37.24  109.21   8.96   3.55     12  71.26  0.84
#
# ...

# %%
# import the necessary libraries
import numpy as np 
import pandas as pd 
import os

# Visualisation libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import pycountry
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot 
import plotly.graph_objs as go
import plotly.offline as py
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
# !pip install chart_studio
import chart_studio.plotly as py
import cufflinks
cufflinks.go_offline()
cufflinks.set_config_file(world_readable=True, theme='pearl')
#py.init_notebook_mode(connected=True)

#Geographical Plotting
import folium
from folium import Choropleth, Circle, Marker
from folium import plugins
from folium.plugins import HeatMap, MarkerCluster

#Racing Bar Chart
# !pip install bar_chart_race
import bar_chart_race as bcr
from IPython.display import HTML

# Increase the default plot size and set the color scheme
plt.rcParams['figure.figsize'] = 8, 5
plt.style.use("fivethirtyeight")# for pretty graphs

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Disable warnings 
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import missingno as msno

from pandas.plotting import lag_plot, autocorrelation_plot
plt.style.use('seaborn-whitegrid')

from termcolor import colored
# Out:
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
print('hello')
# Out:
# hello

# %%
print('hiha')
# Out:
# hiha

# %%
import pandas as pd

df = pd.read_excel('cici.xlsx')
df
# Out:
#                                            Unnamed: 0  \
# 0                                                TAGS
# 1          Salmanul Faris\n\nAmpere\nSenior Recruiter
# 2     Ashish Garg\n\nOptum\nTalent Acquisition Leader
# 3   Sqn Ldr Deepika Thakur (Retd.)\n\nOptum\nSenio...
# 4    Swati Tomar\n\nPayPal\nGlobal Talent Acquisition
# 5   Nishant Christian\n\nTredence Inc.\nTalent Acq...
# 6   Sabareesh Nair\n\nTredence Inc.\nTalent Acquis...
# 7   Sajjan Raj\n\nTredence Inc.\nTalent Acquisitio...
# 8   Saurabh Garg\n\nCarDekho\nSenior Human Resourc...
# 9   Ankit Soam\n\nCarDekho\nAssociate Director - T...
# 10  Pavithra Eshwarappa\n\nHavas Group India\nSeni...
# 11       Mihir Suvanam\n\nLynk\nGlobal Head of People
# 12  Yashika aneja\n\nComviva\nHuman Resources Recr...
# 13       Bailey O'Connor\n\nOptizon Pty Ltd.\nFounder
# 14  Isha Kukreja\n\nShipBob, Inc.\nSenior Talent P...
# 15  Anamika Ojha\n\nCARS24\nDeputy Manager Human R...
# ...

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].fillna('')

# split the text column by return character and convert to a Series
split_text = df['Unnamed: 0'].apply(lambda x: pd.Series(x.split('\n')))
split_text
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ANKIT SHARMA\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\ANKIT SHARMA\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\ANKIT SHARMA\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].fillna('')

# split the text column by return character and convert to a Series
split_text = df['Unnamed: 0'].apply(lambda x: pd.Series(x.split('\n')))

# rename the columns
split_text.columns = ['column1', 'column2', 'column3' , 'column4']

# join the split text columns back to the original DataFrame
df = df.join(split_text)
df
# Out:
#                                            Unnamed: 0  \
# 0                                                TAGS
# 1          Salmanul Faris\n\nAmpere\nSenior Recruiter
# 2     Ashish Garg\n\nOptum\nTalent Acquisition Leader
# 3   Sqn Ldr Deepika Thakur (Retd.)\n\nOptum\nSenio...
# 4    Swati Tomar\n\nPayPal\nGlobal Talent Acquisition
# 5   Nishant Christian\n\nTredence Inc.\nTalent Acq...
# 6   Sabareesh Nair\n\nTredence Inc.\nTalent Acquis...
# 7   Sajjan Raj\n\nTredence Inc.\nTalent Acquisitio...
# 8   Saurabh Garg\n\nCarDekho\nSenior Human Resourc...
# 9   Ankit Soam\n\nCarDekho\nAssociate Director - T...
# 10  Pavithra Eshwarappa\n\nHavas Group India\nSeni...
# 11       Mihir Suvanam\n\nLynk\nGlobal Head of People
# 12  Yashika aneja\n\nComviva\nHuman Resources Recr...
# 13       Bailey O'Connor\n\nOptizon Pty Ltd.\nFounder
# 14  Isha Kukreja\n\nShipBob, Inc.\nSenior Talent P...
# 15  Anamika Ojha\n\nCARS24\nDeputy Manager Human R...
# ...

# %%
df.to_excel('example.xlsx', index=False)

# %%
df = pd.DataFrame({'col1':['op c','op k','op p'] , 'col2':[1,2,3] , 'col3':[1,2,3] })
print(df)
# Out:
#    col1  col2  col3
# 0  op c     1     1
# 1  op k     2     2
# 2  op p     3     3

# %%
c = df['col1'].str.split(' ')
c
# Out:
# 0    [op, c]
# 1    [op, k]
# 2    [op, p]
# Name: col1, dtype: object

# %%
a = df['col1'].apply(pd.Series(df['col1'].str.split(' ')))
a
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 a = df['col1'].apply(pd.Series(df['col1'].str.split(' ')))
#       2 a
#
# File c:\Users\ANKIT SHARMA\miniconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\ANKIT SHARMA\miniconda3\lib\site-packages\pandas\core\apply.py:1098, in SeriesApply.apply(self)
#    1096 # dispatch to agg
#    1097 if is_list_like(self.f):
# -> 1098     return self.apply_multiple()
# ...

# %%
split_text = df['col1'].apply(lambda x: pd.Series(x.split(' ')))
split_text
# Out:
#     0  1
# 0  op  c
# 1  op  k
# 2  op  p

# %%
df['Unnamed: 1'] = df['Unnamed: 1'].apply(lambda x: x.split('@') if x else [])
df
# Out:
#                                            Unnamed: 0  \
# 0                                                TAGS
# 1          Salmanul Faris\n\nAmpere\nSenior Recruiter
# 2     Ashish Garg\n\nOptum\nTalent Acquisition Leader
# 3   Sqn Ldr Deepika Thakur (Retd.)\n\nOptum\nSenio...
# 4    Swati Tomar\n\nPayPal\nGlobal Talent Acquisition
# 5   Nishant Christian\n\nTredence Inc.\nTalent Acq...
# 6   Sabareesh Nair\n\nTredence Inc.\nTalent Acquis...
# 7   Sajjan Raj\n\nTredence Inc.\nTalent Acquisitio...
# 8   Saurabh Garg\n\nCarDekho\nSenior Human Resourc...
# 9   Ankit Soam\n\nCarDekho\nAssociate Director - T...
# 10  Pavithra Eshwarappa\n\nHavas Group India\nSeni...
# 11       Mihir Suvanam\n\nLynk\nGlobal Head of People
# 12  Yashika aneja\n\nComviva\nHuman Resources Recr...
# 13       Bailey O'Connor\n\nOptizon Pty Ltd.\nFounder
# 14  Isha Kukreja\n\nShipBob, Inc.\nSenior Talent P...
# 15  Anamika Ojha\n\nCARS24\nDeputy Manager Human R...
# ...

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].str.split('\n')
df
# Out:
#                                            Unnamed: 0  \
# 0                                              [TAGS]
# 1        [Salmanul Faris, , Ampere, Senior Recruiter]
# 2   [Ashish Garg, , Optum, Talent Acquisition Leader]
# 3   [Sqn Ldr Deepika Thakur (Retd.), , Optum, Seni...
# 4   [Swati Tomar, , PayPal, Global Talent Acquisit...
# 5   [Nishant Christian, , Tredence Inc., Talent Ac...
# 6   [Sabareesh Nair, , Tredence Inc., Talent Acqui...
# 7   [Sajjan Raj, , Tredence Inc., Talent Acquisiti...
# 8   [Saurabh Garg, , CarDekho, Senior Human Resour...
# 9   [Ankit Soam, , CarDekho, Associate Director - ...
# 10  [Pavithra Eshwarappa, , Havas Group India, Sen...
# 11     [Mihir Suvanam, , Lynk, Global Head of People]
# 12  [Yashika aneja, , Comviva, Human Resources Rec...
# 13     [Bailey O'Connor, , Optizon Pty Ltd., Founder]
# 14  [Isha Kukreja, , ShipBob, Inc., Senior Talent ...
# 15  [Anamika Ojha, , CARS24, Deputy Manager Human ...
# ...
